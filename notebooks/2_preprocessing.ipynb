# %%
import pandas as pd
df_preprocessed = pd.read_csv('../data/2_cleaned/cleaned_data.csv')
df_preprocessed.head()
# Out:
#       locality_name  postal_code   price type_of_property subtype_of_property  \
# 0           seneffe         7180  410000            house               villa
# 1        hennuyères         7090  750000            house               house
# 2       la louvière         7100  175000       appartment                flat
# 3  solre-sur-sambre         6560   80000            house               house
# 4              mons         7000  195000            house               house
#
#    number_of_rooms  living_area  equipped_kitchen  furnished  open_fire  \
# 0              4.0        175.0                 1          0          0
# 1              4.0        550.0                 0          0          0
# 2              2.0         76.0                 1          0          0
# 3              3.0        235.0                 0          0          0
# 4              2.0        103.0                 0          0          0
#
# ...

# %%
for col in df_preprocessed.select_dtypes(include="object"):
    print(f"Column: {col}")
    dupes = df_preprocessed[col][df_preprocessed[col].duplicated()].unique().tolist()
    print(dupes)
    print("-----")
    print(len(dupes))
# Out:
# Column: locality_name
# ...
